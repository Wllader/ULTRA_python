# %% [markdown]
# # Nadpis
# ## Podnadpis
# ### PodPodnadpis
#
# odstavec1
#
# odstavec2
# další část odstavce 2
#
# **tučný text**, *kurzíva*, ~~strikethroug~~, [odkaz](https://www.google.com/)
#
# $\frac{a}{b}$
#
# $$
# \frac{c}{d}
# $$

# %%
a = 4
b = 8

a**b
# Out:
# 65536
